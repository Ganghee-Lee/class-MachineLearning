# %%
import numpy as np
import matplotlib.pyplot as plt
'''
1. Data
 - Config
 - Input Data

 2. Linear Model
 - Initialize linear model
 - Visualize data and linear model
'''

# Config
m=1000
a=20
b=-14
learning_rate=0.001
theta0, theta1=27, 48

# Input data
x=np.random.normal(0, 3, size=m)
temp_y=a*x+b
n=np.random.normal(0, 3, size=m)
y=temp_y+n

# Initialize linear model
h=theta1*x+theta0

# Visualize data and linear model
plt.scatter(x, y, color='black')
plt.plot(x, h, color='blue')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Input data')
plt.show()

# %%
'''
3. Objective function
 - Define objective function

4. Gradient Descent
 - Define derivations
 - Update theta0 and theta1
'''

# Define objective function
def objective_function() :
    J = np.sum((h-y)**2) / (2*m)
    return J

# Define derivations
def dev() :    
    dev0=np.sum(h-y) / m
    dev1=np.sum((h-y)*x) / m
    return dev0, dev1

# Update theta0 and theta1
def gradient_descent() :
    return theta0-(learning_rate*dev0), theta1-(learning_rate*dev1)

J_list=[]
theta0_list=[]
theta1_list=[]
# Train
count=0
while(1) :
    count+=1
    J=objective_function()
    J_list.append(J)
    theta0_list.append(theta0)
    theta1_list.append(theta1)
    dev0, dev1 = dev()
    temp0, temp1 = theta0, theta1
    theta0, theta1 = gradient_descent()
    h=theta0+theta1*x
    if(temp0==theta0) and (temp1==theta1) :
        break
print("theta0 : ", theta0)
print("theta1 : ", theta1)
print("loss : ", J)
# Visualize data and linear model
plt.scatter(x, y, color='black')
plt.plot(x, h, color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear regression results')
plt.show()
# Out:
# theta0 :  -14.01086849962189
# theta1 :  20.01021213746574
# loss :  4.2614298095001635

# %%
plt.plot(J_list, color='blue')
plt.xlabel("iteration")
plt.ylabel("cost")
plt.title("Energy values")
plt.show()
# Out:
# [3994.335724697696, 3940.857153968646, 3888.2365625041834, 3836.459838088421, 3785.513101339588, 3735.382701867132, 3686.05521449224, 3637.5174355307445, 3589.7563791373846, 3542.7592737104083, 3496.5135583555157, 3451.0068794081685, 3406.2270870133025, 3362.162231761491, 3318.800561380636, 3276.1305174822546, 3234.140732361485, 3192.820025849897, 3152.157402220256, 3112.1420471423735, 3072.7633246892037, 3034.010774392356, 2995.8741083462096, 2958.3432083598245, 2921.4081231558603, 2885.059065615737, 2849.286410070252, 2814.080689634934, 2779.4325935893644, 2745.3329647997584, 2711.7727971840964, 2678.7432332190806, 2646.235561488252, 2614.241214270575, 2582.751765168816, 2551.7589267770813, 2521.254548386842, 2491.2306137308233, 2461.679238764139, 2432.592669482044, 2403.9632797737067, 2375.7835693114102, 2348.046161474586, 2320.743801308121, 2293.869353514358, 2267.4158004782403, 2241.376240325057, 2215.7438850102367, 2190.5120584406845, 2165.67419462711, 2141.223835866868, 2117.154630956782, 2093.460333435473, 2070.134799854693, 2047.171988079196, 2024.565955614668, 2002.3108579632578, 1